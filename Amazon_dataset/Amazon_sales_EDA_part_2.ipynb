# %% [markdown]
# # EDA and some visialisations #

# %%
#importing all needed libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("amazon.csv")  #reading file
df.head(3)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# ...

# %%
df.tail(3)
# Out:
#       product_id                                       product_name  \
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# 1462       ₹3,080                 28%    3.6          468
# 1463       ₹1,890                 26%      4        8,031
# 1464       ₹3,690                 22%    4.3        6,987
#
#                                           about_product  \
# 1462  International design and styling|Two heat sett...
# ...

# %%
# cleaning up from useless symbols, like per cent sign etc.

for col in ['discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count']:
    df[col] = df[col].astype(str).str.replace('₹', '').str.replace('%', '').str.replace(',', '').str.replace('nan', '0')
    df[col] = pd.to_numeric(df[col].str.replace('[^0-9.]', '', regex=True), errors='coerce').fillna(0)

df.head(2)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2         24269
# 1         349.0                   43     4.0         43994
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
# ...

# %%
df[['discounted_price','actual_price','discount_percentage']].describe()
# Out:
#        discounted_price   actual_price  discount_percentage
# count       1465.000000    1465.000000          1465.000000
# mean        3125.310874    5444.990635            47.691468
# std         6944.304394   10874.826864            21.635905
# min           39.000000      39.000000             0.000000
# 25%          325.000000     800.000000            32.000000
# 50%          799.000000    1650.000000            50.000000
# 75%         1999.000000    4295.000000            63.000000
# max        77990.000000  139900.000000            94.000000

# %%
df['actual_price'].agg(["max" ,"min"])
# Out:
# max    139900.0
# min        39.0
# Name: actual_price, dtype: float64

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    181
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.0      4
# 3.1      4
# 5.0      3
# 4.8      3
# 3.2      2
# 2.8      2
# 2.3      1
# 0.0      1
# 2.0      1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %%
df.sort_values(by='rating_count',ascending=False).head(10)[['product_name','rating','rating_count']]
# Out:
#                                           product_name  rating  rating_count
# 12   AmazonBasics Flexible Premium HDMI Cable (Blac...     4.4        426973
# 65   Amazon Basics High-Speed HDMI Cable, 6 Feet (2...     4.4        426973
# 47   Amazon Basics High-Speed HDMI Cable, 6 Feet - ...     4.4        426973
# 684  AmazonBasics Flexible Premium HDMI Cable (Blac...     4.4        426972
# 400  boAt Bassheads 100 in Ear Wired Earphones with...     4.1        363713
# 352  boAt Bassheads 100 in Ear Wired Earphones with...     4.1        363713
# 584  boAt BassHeads 100 in-Ear Wired Headphones wit...     4.1        363711
# 370  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...     4.1        313836
# 371  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...     4.1        313836
# 473  Redmi 9A Sport (Carbon Black, 2GB RAM, 32GB St...     4.1        313832

# %% [raw]
# Category: USB Cables (Computers & Accessories)
# Top listings are mainly braided charging/data sync cables for iPhones, USB Type-C, and laptops. These products appear in multiple variants (e.g., length, color, connector type).
#
# Business Insight: The company should ensure strong supply chain continuity for these high-demand accessories. Since most listings are similar, bundling options or differentiation by quality/warranty could help improve margins.
#
# Category: Smartwatches (Electronics → Wearable Technology)
# Dominated by Fire-Boltt brand models with features like calling, AMOLED displays, and health tracking. Also includes a listing from boAt, indicating competition among budget-friendly Indian brands.
#
# Business Insight: These products are in high demand. The company can benefit by running brand-focused promotions (e.g., Fire-Boltt bundles) and pushing feature comparison tools to help buyers choose.
#
# Category: Smartphones
# Multiple models from Samsung and Redmi, with variations in RAM/storage. Listings mostly fall under mid-range to budget-friendly segments.
#
# Business Insight: These are likely top revenue drivers. The company can offer exchange programs, accessories bundling (e.g., phone + case/charger), and EMI offers to increase conveons### .
#
# Category: Smelevi#####sions
# Brands include Samsung, LG, Redmi, and Mi — covering popular screen sizes and smart features. Listings include specific screen sizes and OS compatibility (Android, webOS).
#
# Business Insight: TVs are high-ticket items. The company should focus on enhancing product pages with visuals, review summaries, and delivery/installation scheduling to increase trust and pu i##### ##### ntent.
# y: In-
#
# C#### #####Headphones
# Top products include JBL, Boult, boAt, and Noise — all Indian market favorites. Key selling points: battery life, bass quality, calling features, and waterproofing.
#
# Business Insight: Customers in this category care about comfort and audio quality. A/B testing of product titles and descriptions highlighting these features can help improve click-through and sales.
